# %% [markdown]
# <a href="https://colab.research.google.com/github/dubanmojica/programacion1/blob/main/Untitled38.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
try:
  nombre = input("ingrese su nombre y apellido sin espacios: "). lower()
  edad = input("ingrese suu edad: ")
  #validar el nombre
  if not re.fullmatch(r"[a-zA-Z]+", nombre):
    raise ValueError("El nombre solo debe de contener letras")
    #validar edad
  if not re.fullmatch(r"\d{3}+", edad):
    raise ValueError("la edad debe contener numeros")
    #crear conntraseña
  contaseña = nombre[:3] + edad + "@2026"
  print("contraseña generada")
  print(contraseña)
except ValueError as e:
  print("error:", e)
# Out:
# ingrese su nombre y apellido sin espacios: duban
# ingrese suu edad: 17
# error: la edad debe contener numeros

# %%
import re

try:
    nombre = input("Ingrese su nombre y apellido sin espacios: ").lower()
    edad = input("Ingrese su edad: ")
    # Validar nombre
    if not re.fullmatch(r"[a-zA-Z]+", nombre):
        raise ValueError("El nombre solo debe contener letras")
    # Validar edad
    if not re.fullmatch(r"\d+", edad):
        raise ValueError("La edad debe contener solo números")
    # Crear contraseña
    contrasena = nombre[:3] + edad + "@2026"
    print("Contraseña generada:")
    print(contrasena)
except ValueError as e:
    print("Error:", e)
# Out:
# Ingrese su nombre y apellido sin espacios: dubanmojica
# Ingrese su edad: 17
# Contraseña generada:
# dub17@2026

# %%
try:
    # Convertimos a minúsculas igual que en tu código
    nombre = input("Ingrese su nombre y apellido sin espacios: ").lower()
    edad = input("Ingrese su edad: ")

    # Validar nombre: .isalpha() verifica que TODO sean letras del alfabeto (A-Z)
    # Al igual que tu regex original, rechazará espacios, números y caracteres especiales
    if not nombre.isalpha():
        raise ValueError("El nombre solo debe contener letras")

    # Validar edad: .isdigit() verifica que TODO sean números enteros (0-9)
    if not edad.isdigit():
        raise ValueError("La edad debe contener solo números")

    # Crear contraseña (exactamente la misma combinación)
    contrasena = nombre[:3] + edad + "@2026"

    print("Contraseña generada:")
    print(contrasena)

except ValueError as e:
    print("Error:", e)
# Out:
# Ingrese su nombre y apellido sin espacios: dubanmojica
# Ingrese su edad: 017
# Contraseña generada:
# dub017@2026

# %%
import re

try:
    nombre = input("Ingrese su nombre y apellido sin espacios: ").lower()
    apellido = input("ingrese su apliido: ").lower()
    # Validar nombre
    if not re.fullmatch(r"[a-zA-Z]+", nombre):
        raise ValueError("El nombre solo debe contener letras")
    # Validar edad
    if not re.fullmatch(r"\d+", edad):
        raise ValueError("La edad debe contener solo números")
    # Crear correo
    correo = nombre + apellido + "@uis.edu.co"
    print("correo generado")
    print(correoa)
except ValueError as e:
    print("Error:", e)
# Out:
# Ingrese su nombre y apellido sin espacios: dubanmojica
# ingrese su apliido: mojica
# correo generado
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_21163/2579079600.py in <cell line: 0>()
#      13     correo = nombre + apellido + "@uis.edu.co"
#      14     print("correo generado")
# ---> 15     print(correoa)
#      16 except ValueError as e:
#      17     print("Error:", e)
#
# NameError: name 'correoa' is not defined

# %%
import re

try:
    nombre = input("Ingrese su nombre: ").lower()
    apellido = input("ingrese su apliido: ").lower()
    CC = input("ingrese su CC o TI: ")
    # Validar nombre
    if not re.fullmatch(r"[a-zA-Z]+", nombre):
        raise ValueError("nombre invalido ")
    if not re.fullmatch(r"[a-zA-Z]+", apellido):
        raise ValueError("apellido invalido ")
    # Validar edad
    if not re.fullmatch(r"\d+", CC):
        raise ValueError("CC O TI invalido")
    # Crear correo
    correo = nombre + apellido + CC[:3] + "@uis.edu.co"
    print("correo generado")
    print(correo)
except ValueError as e:
    print("Error:", e)
# Out:
# Ingrese su nombre y apellido sin espacios: duban
# ingrese su apliido: mojica
# ingrese su CC o TI: 1029649726
# correo generado
# dubanmojica102@uis.edu.co

# %%
import re
try:
 nombre_completo = input("Ingrese su nombre completo: ").lower()
 # Validar que solo haya letras y espacios
if not re.fullmatch(r"[a-zA-Záéíóúñ\s]+", nombre_completo):
   raise ValueError("Solo se permiten letras y espacios")
  partes = nombre_completo.split()
 # Validar mínimo nombre y apellido
if len(partes) < 2:
  raise ValueError("Debe ingresar al menos nombre y apellido")
 # Caso: un nombre y un apellido
if len(partes) == 2:
   primer_nombre = partes[0]
   primer_apellido = partes[1]
   orreo = primer_nombre[0] + primer_apellido + "@gmail.com"
 # Caso: dos nombres y un apellido
elif len(partes) == 3:
     primer_nombre = partes[0]
     primer_apellido = partes[1]
     segundo_apellido = partes[2]
     correo = (
 primer_nombre[0]
 + primer_apellido
 + segundo_apellido[0]
 + "@gmail.com"
 )
 # Caso: dos nombres y dos apellidos
else:
  primer_nombre = partes[0]
  segundo_nombre = partes[1]
  primer_apellido = partes[2]
  segundo_apellido = partes[3]
  correo = (
      primer_nombre[0]
      + segundo_nombre[0]
      + primer_apellido
      + segundo_apellido[0]
      + "@gmail.com"
 )
 print("Correo generado:")
 print(correo)
except ValueError as e:
 print("Error:", e

# %%
import re

try:
    nombre_completo = input("Ingrese su nombre completo: ").lower()

    # Validar que solo haya letras y espacios
    if not re.fullmatch(r"[a-zA-Záéíóúñ\s]+", nombre_completo):
        raise ValueError("Solo se permiten letras y espacios")

    partes = nombre_completo.split()

    # Validar mínimo nombre y apellido
    if len(partes) < 2:
        raise ValueError("Debe ingresar al menos nombre y apellido")

    # Caso: un nombre y un apellido
    if len(partes) == 2:
        primer_nombre = partes[0]
        primer_apellido = partes[1]
        correo = primer_nombre[0] + primer_apellido + "@gmail.com"

    # Caso: dos nombres y un apellido
    elif len(partes) == 3:
        primer_nombre = partes[0]
        primer_apellido = partes[1]
        segundo_apellido = partes[2]
        correo = primer_nombre[0] + primer_apellido + segundo_apellido[0] + "@gmail.com"

    # Caso: dos nombres y dos apellidos (o más)
    else:
        primer_nombre = partes[0]
        segundo_nombre = partes[1]
        primer_apellido = partes[2]
        segundo_apellido = partes[3]
        correo = (
            primer_nombre[0]
            + segundo_nombre[0]
            + primer_apellido
            + segundo_apellido[0]
            + "@gmail.com"
        )

    print("Correo generado:")
    print(correo)

except ValueError as e:
    print("Error:", e)
# Out:
# Ingrese su nombre completo: mario camilo fernando vargas duran
# Correo generado:
# mcfernandov@gmail.com
