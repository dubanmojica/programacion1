# %% [markdown]
# <a href="https://colab.research.google.com/github/dubanmojica/programacion1/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# nombre: deyner duban mojica bernal

# %% [markdown]
# parte II

# %% [markdown]
# intruccion 1:

# %%
A = (1, 2, 3, 4)
B = (1, 7, 7, 6)

# %%
1 in B
# Out:
# True

# %%
7 in B
# Out:
# True

# %%
1 in A
# Out:
# True

# %%
2 in A
# Out:
# True

# %%
3 in A
# Out:
# True

# %%
4 in A
# Out:
# True

# %% [markdown]
# la sentencia in se utliza para determinar si un elemnto pertenece a una tupla
# o no . el elemnto de salida al utilizar la sentencia es de tipo booleano

# %%
B.count(7)
# Out:
# 2

# %% [markdown]
# el metodo count aplicado en una tupla cuenta cuantas veces aparece la componenente

# %%
B.count(10)
# Out:
# 0

# %% [markdown]
# si un elemento no esta en ninguna componenete de mi tuplla el metodo count devuelve 0

# %% [markdown]
# instruccion 2

# %%
datos2 = {"a":1, "b":2, "c":3, "d":4}

# %%
datos2.pop("d", None)
datos2
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# el metodo por si mismo no tiene salida, para mostrar que hace el metodo explicitamente se debe mostrar una vez se ejecuta.

# %% [markdown]
# el metodo pop aplicado a un diccionario eveluado en una clave, elimina dicha clave junto a su respectivo valor.

# %%
datos2.pop("e")
datos2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_415/1352860358.py in <cell line: 0>()
# ----> 1 datos2.pop("e")
#       2 datos2
#
# KeyError: 'e'

# %% [markdown]
# al evaluar el metodo pop en una clave no exixtente se tiene como salida un error.

# %% [markdown]
# INSTRUCCION 3

# %%
datos3 = {1:"a", 2:"b", 3:"c", 4:"d"}

# %%
datos3.items()
# Out:
# dict_items([(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd')])

# %%
for i in datos3.items():
  print(i)
# Out:
# (1, 'a')
# (2, 'b')
# (3, 'c')
# (4, 'd')

# %% [markdown]
# la salida al aplicar el metodo items en un diccionario corresponde a las tuplas (clave,valor) GENERADAS APARTIR DEL DICCIONARIO

# %%
type(datos3.items())
# Out:
# dict_items

# %% [markdown]
# el tipo de objeto que tiene la salida al aplicar el metodo items en un diccionario es de tipo dict_items

# %%
datos3.items()
# Out:
# dict_items([(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd')])

# %% [markdown]
# explicitamente en un objeto se trasfroma todos las componenetes clave_valor de un diccionario en tuplas.

# %%
m = 6
for n in range(0, m + 1):
 if n % 2 == 0:
   print(n, "es par y su doble es", n * 2)
 else:
   print(n, "es impar y su triple es", n * 3)
# Out:
# 0 es par y su doble es 0
# 1 es impar y su triple es 3
# 2 es par y su doble es 4
# 3 es impar y su triple es 9
# 4 es par y su doble es 8
# 5 es impar y su triple es 15
# 6 es par y su doble es 12

# %%
def reconocerparoimpar(m)
  if m.is_integer() and m >= 0:
    if m % 2 == 0:
      print(m, "es par y su doble es", m * 2)
    else:
      print(m, "es impar y su triple es", m * 3)
  elif m,is_integer() and m < 0:
        print("el numero es negativo")
  else:
          print("el numero no es entero")
# Out:
#   File "/tmp/ipykernel_415/2885695726.py", line 1
#     def reconocerparoimpar(m)
#                              ^
# SyntaxError: expected ':'

# %% [markdown]
# codigo 2

# %%
def contador_vocales1(palabra):
 letras = "aeiou"
 letras1 = "bcdfghjklmnñpqrstvwxyz"
 contador = 0
 contador1 = 0
 contador2 = 0

 for letra in palabra.lower():
  if letra in vocales:
    contador += 1
  elif letra in consonantes:
    contador1 += 1
  else:contador2 += 1
 return({"Cantidad de vocales:": contador,
 "Cantidad de consonates:": contador1,
 "Cantidad de otros caracteres:": contador2})

# %%
def contador_vocales1(palabra):
 letras = "aeioubcdfghjklmnñpqrstvwxyz"
 letras1 = letras.upper()
 numeros = "1234567890"
 espacio = " "
 contador = 0
 contador1 = 0
 contador2 = 0
 contador3 = 0
 contador4 = 0

 for letra in palabra:
  if letra in letras:
    contador += 1
  elif letra in letras1:
    contador1 += 1
  elif letra in numeros:
    contador2 += 1
  elif letra in espacio:
    contador3
  else:contador4 += 1
 return({"Cantidad de vocales:": contador,
          "Cantidad de consonates:": contador1,
          "Cantidad de números:": contador2,
          "Cantidad de espacios:": contador3,
          "Cantidad de otros caracteres:": contador4})

# %%
def reconocerparimpar(m):
  try:
    m = float(m)
    if m.is_integer() and m >= 0:
      for n in range(0, int(m + 1)):
        if n % 2 == 0:
          print(n, "es par y su doble es", n * 2)
        else:
          print(n, "es impar y su triple es", n * 3)
    elif m.is_integer() and m < 0:
        print("El número es negativo")
    else:
        print("El número no es entero")
  except ValueError:
    print("El valor ingresado no es un número")

# %%
def contador_vocales1(palabra):
  vocales = "aeiou"
  consonantes = "bcdfghjklmnñpqrstvwxyz"
  numeros = "0123456789"
  espacio = " "
  contador = 0
  contador1 = 0
  contador2 = 0
  contador3 = 0
  contador4 = 0

  for letra in palabra.lower():
    if letra in vocales:
      contador += 1
    elif letra in consonantes:
      contador1 += 1
    elif letra in numeros:
      contador2 += 1
    elif letra in espacio:
      contador3 += 1
    else:
      contador4 += 1
  return({"Cantidad de vocales:": contador,
          "Cantidad de consonates:": contador1,
          "Cantidad de números:": contador2,
          "Cantidad de espacios:": contador3,
          "Cantidad de otros caracteres:": contador4})

# %%
contador_vocales1("hola.425")
# Out:
# {'Cantidad de vocales:': 2,
#  'Cantidad de consonates:': 2,
#  'Cantidad de números:': 3,
#  'Cantidad de espacios:': 0,
#  'Cantidad de otros caracteres:': 1}

# %%
palabras = input("ingrese una cadena: ")
contador_vocales1(palabras)
# Out:
# ingrese una cadena: esternocleidomastoideo34
# {'Cantidad de vocales:': 11,
#  'Cantidad de consonates:': 11,
#  'Cantidad de números:': 2,
#  'Cantidad de espacios:': 0,
#  'Cantidad de otros caracteres:': 0}

# %%
list(map(float, v1))
# Out:
# [3.5, 2.0, 3.0]

# %%
def producto_cruz(v1, v2):
 try:
  v1 = list(float 3.5, 2, 3)
  v2 = list(3.8, 5, 6)
  if len(v1) != 3 or len(v2) != 3:
    return "Los vectores deben ser de 3 dimensiones"
  else:
    resultado = [
        v1[1]*v2[2] - v1[2]*v2[1],
        v1[2]*v2[0] - v1[0]*v2[2],
        v1[0]*v2[1] - v1[1]*v2[0]
 ]
    return resultado
 except TypeError:
  return "Los vectores deben ser de tipo numérico"
# Out:
#   File "/tmp/ipykernel_415/2272400440.py", line 3
#     v1 = list(float 3.5, 2, 3)
#               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
v1 = [3.5, 2, 3]
v2 = [3.8, a, 6]
producto_cruz(v1, v2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_415/138214863.py in <cell line: 0>()
#       1 v1 = [3.5, 2, 3]
# ----> 2 v2 = [3.8, a, 6]
#       3 producto_cruz(v1, v2)
#
# NameError: name 'a' is not defined
