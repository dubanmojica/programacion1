# %% [markdown]
# <a href="https://colab.research.google.com/github/dubanmojica/programacion1/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def saludar():     #se define y se describe la funcion
  "la funcion que te saluda"
  print("saludar")

# %%
saludar()
# Out:
# hola mundo

# %%
saludar # aca se da la describcion que se dio arriba de "la funcion que te ayuda"
# Out:
# <function __main__.saludar()>

# %%
def saludar(nombre):
  print("hola", nombre)

# %%
saludar(duban)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-787/129956885.py in <cell line: 0>()
# ----> 1 saludar(duban)
#
# NameError: name 'duban' is not defined

# %%
def saludar(nombre="duban"):
    print("hola", nombre)
saludar()
saludar(nombre = "duban")
# Out:
# hola duban
# hola duban

# %% [markdown]
# en este caso denota el argumento de la funcion

# %%
def sumar(a,b):
  print(a+b)

# %%
def sumar(a,b):
  return(a+b)

# %%
resultado = sumar(a = 3, b = 5)
resultado
# Out:
# 8

# %%
def multiplicacion(a,b):
    return(a*b)

# %%
resultado = multiplicacion(a = 6, b= 4)
resultado
# Out:
# 24

# %% [markdown]
# note la diferencia: print() muestra, mientras que return devuelve

# %%
def operaciones(a,b):
  suma = a+b
  resta = a-b
  return suma, resta
s, r = operaciones(b = 10, a = 5)
print(s, r)
# Out:
# 15 -5

# %%
def operaciones(a,b):
  suma = a+b
  resta = a-b
  return suma, resta
s = operaciones(b = 10, a = 5)
print(s[0])
# Out:
# 15

# %%
def operaciones(a,b):
  multiplicacion = a*b
  print(multiplicacion, multiplicacion)
  return [multiplicacion, multiplicacion**2]
m,n = operaciones(b=10, a=2)
print(m,n)
# Out:
# 20 20
# 20 400

# %%
def fib(n):
    a, b = 0, 1
    while a < n:
      print(a,end=" ")
      a, b = b, a+b
print(fib(12))
# Out:
# 0 1 1 2 3 5 8 None

# %%
def fib(n):
    a, b = 0, 1
    while a < n:
      print(a,end=" ")
      a, b = b, a+b
(fib(12))
# Out:
# 0 1 1 2 3 5 8

# %%
def es_par(numero):
  if numero % 2 == 0:
    return "es par"
  else:
    return "es impar"

# %%
a = 4
es_par(a)
# Out:
# 'es par'
