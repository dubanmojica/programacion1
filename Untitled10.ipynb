# %% [markdown]
# <a href="https://colab.research.google.com/github/dubanmojica/programacion1/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sumar( a, b ):
  return a + b

# %%
suma = lambda a, b: a + b
suma(3, 4)
# Out:
# 7

# %%
sumar = lambda a, b: a + b
print(sumar(3, 5))
# Out:
# 8

# %%
multiplicar = lambda a, b: a*b
print(sumar(3, 4))
# Out:
# 7

# %%
ultimoele = lambda palabra: palabra[-1]
ultimoele("casa")
# Out:
# 'a'

# %%
def cuadrado(x):
  return x**2

# %%
list(map(cuadrado, [1, 2, 3, 4]))
# Out:
# [1, 4, 9, 16]

# %%
list(map(lambda x: x**2, [1, 2, 3, 4]))
# Out:
# [1, 4, 9, 16]

# %%
lambda1 = list(map(cuadrado, [1, 2, 3, 4]))
lambda1
# Out:
# [1, 4, 9, 16]

# %%
def es_par(numero):
  return numero % 2 == 0

# %%
def es_par(numero):
  return numero % 2 == 0
es_par(5)
# Out:
# False

# %%
par = lambda numero: numero % 2 == 0
par(5)
# Out:
# False

# %%
list(filter(es_par, [1, 2, 3, 4]))
# Out:
# [2, 4]

# %%
list(filter(lambda numero: numero % 2 == 0, [1, 2, 3, 4]))
# Out:
# [2, 4]

# %%
personas = {("juan", 20), ("ana", 18), ("pedro", 19)}
def clave(diccionario):
  return sorted([i for i in diccionario[0]])

# %%
clave(personas)
# Out:
# [('ana', 18), ('juan', 20), ('pedro', 19)]

# %%
ordenado = sorted(personas, key = lambda persona: persona)
ordenado
# Out:
# [('ana', 18), ('juan', 20), ('pedro', 19)]

# %%
ordenado = sorted(personas, key = lambda persona: persona)
ordenado

# %%
datos = [("a", 3, "x"), ("b", 1, "z"), ("c", 2, "y")]

ordenado = sorted(datos, key=lambda x: x[2])

print(ordenado)
# Out:
# [('a', 3, 'x'), ('c', 2, 'y'), ('b', 1, 'z')]

# %%
def tercerindice(lista):
  return lista[2]

# %%
sorted(datos, key = tercerindice)
# Out:
# [('a', 3, 'x'), ('c', 2, 'y'), ('b', 1, 'z')]

# %%
tercerindice((1,2,3))
# Out:
# 3

# %%
sorted(datos, key = tercerindice)
# Out:
# [('a', 3, 'x'), ('c', 2, 'y'), ('b', 1, 'z')]

# %%
return[i[2] for i in lista]

# %%
def tercerindice(lista):
  for i in lista:
    return i[2]

# %%
tercerindice

# %%
datos = [("a", 3, "x"), ("b", 1, "z"), ("c", 2, "y")  ]
def tercerindice(lista):
  return[i[2] for i in lista]
sorted(tercerindice(datos))
# Out:
# ['x', 'y', 'z']

# %%
def longitud(palabra):
  return len(palabra)

# %%
sorted(["ana", "carro"], longitud)

# %%
palabras = ["sol", "elefante", "luna", "estrella"]
ordenado = sorted(palabras, key=lambda x: len(x))
print(ordenado)
# Out:
# ['sol', 'luna', 'elefante', 'estrella']

# %%
palabras = ("sol", "elefante", "luna", "estrella")

# %%
def longitud(palabra):
  return len(palabra)

# %%
longitud("casa")
# Out:
# 4

# %%
palabras = ["sol", "elefante", "luna", "estrella"]
sorted(palabras, key = longitud)
# Out:
# ['sol', 'luna', 'elefante', 'estrella']

# %%
sorted(palabras, key = lambda palabras : len(palabras))
# Out:
# ['sol', 'luna', 'elefante', 'estrella']

# %%
listanumeros = [("a", 4.5), ("b", 2.5), ("c", 3,8), ("d", 5.1)]

# %%
def valor(lista):
  return lista[1]

# %%
from functools import reduce
reduce(lambda x, y: x + y, [4, 5, 6, 7])
# Out:
# 22

# %%
datos = [("camila", 20), ("ana", 18), ("pedro", 25)]

# %%
list(filter(lambda x: x[1] > 20, datos))
# Out:
# [('pedro', 25)]

# %%
palabras = ["sol", "elefante", "luna", "estrella"]
largas = list(filter(lambda x: len(x) > 5, palabras))
print(largas)
# Out:
# ['elefante', 'estrella']
