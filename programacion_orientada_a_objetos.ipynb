# %% [markdown]
# <a href="https://colab.research.google.com/github/dubanmojica/programacion1/blob/main/programacion_orientada_a_objetos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# programacion orientada a objetos

# %% [markdown]
# un objeto tiene atributos = es decir lo que tiene el objeto + metodos que seria las acciones que ejecuta el objeto

# %% [markdown]
# clase: una clase es una plantilla en el cual se puede atribuir cualidades o funciones, tambien es un molde para crear objetos

# %%
class persona:
  pass

# %%
persona
# Out:
# __main__.persona

# %%
from typing import Self
class persona:
  #construir
  def __init__(self, nombre, edad, estatura, peso):
      self.nombre = nombre #atributo
      self.edad = edad  #atributo
      self.estatura = estatura #atributo
      self.peso = peso #Atributo
  def imc(self):
      return self.peso / (self.estatura ** 2)
  def saludar(self):
      print("hola", self.nombre, "tu IMC es", self.imc())

# %%
persona1 = persona("duban", 17, 1.71, 72)
persona1.saludar()
# Out:
# hola duban tu IMC es 24.622960911049557

# %%
persona2 = persona("carlos", 20, 1.80, 80)
persona2.saludar()
# Out:
# hola carlos tu IMC es 24.691358024691358

# %%
persona1.nombre
# Out:
# 'duban'

# %%
persona2.nombre
# Out:
# 'carlos'

# %%
persona2.peso
# Out:
# 80

# %% [markdown]
# la clase se define que informacion tendraan los objetos (atributo) y que podran hacer(metodos)
#
#
# el constructor init
# def** ini**t(self, atributos):
#
#
# este metodo se llama automaticamente (por convecion) cuando se crea un onjeto.
#
#      . init: es un metodo especial de python. se ejecuta automaticamente. sirve para iniciar atributos.
#      . sefl representa el objeto actual. permite guardar informacion propia de cada objeto.
#   es decir, en persona 1, self seran los atributos de la persona 1.

# %%
class calculadora:
  def __init__(self, a, b):
     self.a = a #atributo
     self.b = b #atributo
  def sumar(self):
      return self.a + self.b
  def restar(self):
      return self.a - self.b
  def multiplicar(self):
      return self.a * self.b
  def dividir(self):
      try:
          return self.a / self.b
      except ZeroDivisionError:
          print("Error: No se puede dividir entre cero.")
          return None

# %%
calcula1 = calculadora(2, 4)
calcula1.dividir()
# Out:
# 0.5

# %%
calucula2 = calculadora(2,0)
calcula2 = calculadora(2,0)
calcula2.dividir()
# Out:
# Error: No se puede dividir entre cero.

# %%
calc = calculadora(3,4)

print("suma:" , calc.sumar())
print("resta:" , calc.restar())
print("multiplicacion:" , calc.multiplicar())
print("division:" , calc.dividir())
# Out:
# suma: 7
# resta: -1
# multiplicacion: 12
# division: 0.75

# %%
a = float(input("Digite o primeiro número: "))
b = float(input("Digite o segundo númmero: "))
calc = calculadora(a,b)

print("suma:" , calc.sumar())
print("resta:" , calc.restar())
print("multiplicacion:" , calc.multiplicar())
print("division:" , calc.dividir())
# Out:
# Digite o primeiro número: 4
# Digite o segundo númmero: 2
# suma: 6.0
# resta: 2.0
# multiplicacion: 8.0
# division: 2.0

# %%
try:
  a = float(input("Digite o primeiro número: "))
  b = float(input("Digite o segundo númmero: "))
  calc = calculadora(a,b)

  print("suma:" , calc.sumar())
  print("resta:" , calc.restar())
  print("multiplicacion:" , calc.multiplicar())
  print("division:" , calc.dividir())
except ValueError:
    print("debes ingresar numeros validos")
except ZeroDivisionError:
    print("no se puede dividir entre cero")
# Out:
# Digite o primeiro número: 4
# Digite o segundo númmero: 0
# suma: 4.0
# resta: 4.0
# multiplicacion: 0.0
# Error: No se puede dividir entre cero.
# division: None

# %%
class estudiante:
    def __init__(self,nombre,nota):
        self.nombre=nombre
        self.nota=nota
    def aprobar(self):
        if self.nota >= 3.0:
          print(self.nombre, "Aprobó")
        else:
          print(self.nombre, "Reprobo")

# %%
persona1 = estudiante("galindo",3.4)
persona1.aprobar()
# Out:
# galindo Aprobó

# %%
estudiante
# Out:
# __main__.estudiante

# %%
class estudiante:
  """metodos aprobar"""
  def __init__(self,nombre,nota):
      self.nombre=nombre
      self.nota=nota
  def aprobar(self):
    if self.nota >= 3.0:
       print(self.nombre, "Aprobó")
    else:
       print(self.nombre, "Reprobo")

# %%
estudiante
# Out:
# __main__.estudiante

# %%
e1 = estudiante("mario", 4.5)
e1

# %%
e1.aprobar()
# Out:
# mario Aprobó

# %%
class Animal:
  def hablar(self): #metodo
      print("el animal hace un sonido")
class Perro(Animal): #se puede definir una clase dentro de otra
  def ladrar(self):#metodo
      print("gua gua")

# %%
p= Perro()
p.hablar()
p.ladrar()
# Out:
# el animal hace un sonido
# gua gua

# %% [markdown]
# es un ejemplo de programacion heredada

# %%
class cuentabancaria:
    def __init__(self, titular, saldo):
      self.titular = titular
      self.saldo = saldo # Corrected: use 'saldo' argument
    def mostrar_saldo(self):
        print("Saldo:", self.saldo)
    def depositar(self, cantidad):
      if cantidad > 0:
        self.saldo += cantidad

# %%
e1 = cuentabancaria("juan", 1000)
e1.mostrar_saldo()
e1.depositar(500) # Corrected: method name from 'ingresar' to 'depositar'
e1.mostrar_saldo()
# Out:
# Saldo: 1000
# Saldo: 1500

# %%
class perro:
  def hablar(self):
      print("el animal hace un sonido")
class perro:
  def sonido(self):
      print("gua gua")
class gato:
  def sonido(self):
      print("mia mia")
class vaca:
  def sonido(self):
      print("muu muee")

# %%
class cuentabancaria:
    def __init__(self, titular, saldo):
      self.titular = titular
      self.saldo = saldo
    def depositar(self, cantidad):
      self.saldo += cantidad #al saldo le sumamos la cantidad
    def retirar(self, cantidad):
      self.saldo -= cantidad #al saldo le restamos la cantidad
    def mostrar_saldo(self):
        print("el Saldo del titular luego del movimiento es :", self.saldo)

# %%
cuenta = cuentabancaria("juan", 1000)
cuenta.mostrar_saldo()
cuenta.depositar(500)
cuenta.mostrar_saldo()
cuenta.retirar(200)
cuenta.mostrar_saldo()
# Out:
# el Saldo del titular luego del movimiento es : 1000
# el Saldo del titular luego del movimiento es : 1500
# el Saldo del titular luego del movimiento es : 1300
