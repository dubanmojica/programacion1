# %% [markdown]
# <a href="https://colab.research.google.com/github/dubanmojica/programacion1/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# nombre: Deyner Duban Mojica Bernal

# %% [markdown]
# parte: II

# %% [markdown]
# INSTRUCCUION : 2

# %%
A = {2,4,6,8,10}
B = {1,2,3,4,5}

# %%
A.difference(B)
# Out:
# {6, 8, 10}

# %% [markdown]
# El metodo .difference sirve para mirar que elemtos de mis conjuntos son diferententes en el caso del conjunto A al aplicarle el metodo miramos que elementos tiene de diferente con el conjunto B y el nuevo conjunto serua {6, 8, 10}

# %%
A.symmetric_difference(B)
# Out:
# {1, 3, 5, 6, 8, 10}

# %% [markdown]
# EL metodo .symmetric_difference es mas general que el metodo .difference ya que el metodo.symmetric_difference nos da los elementos que no tienen en comun los dos conjuntos con este metodo nos da como resultado el conjunto {1, 3, 5, 6, 8, 10}

# %% [markdown]
# INSTRUCCION:2

# %%
A = {2,4,6,8,10,9,3}
B = {2,4,6,8,10}

# %%
A.issuperset(B)
# Out:
# True

# %%
C = {1,2,3,4,5}
N = {6,7,8,9,5}

# %%
C.issuperset(N)
# Out:
# False

# %% [markdown]
# el metodo .issuperset() nos sirve para revisar si los elemntos de un conjunto esta contenidos en el otro conjunto y nos da una respuesta de tipo booleano

# %%
A = {2,4,6,8,10,9,3}
B = {2,4,6,8,10}

# %%
A.isdisjoint(B)
# Out:
# False

# %%
C = {1,2,3,4,5}
N = {6,7,8,9,10}

# %%
C.isdisjoint(N)
# Out:
# True

# %% [markdown]
# EL cambio el metodo .isdisjoint nos sirve si los elemntos de mis conjuntos son secuenciales mostrandonos una respuesta de tipo booleano que seria true si son valores seguidos y false si no lo son

# %% [markdown]
# Instrucción 3

# %%
datos2 = {"a":100,"b":200,"c":300}

# %%
datos2.update({"d": 400})
datos2
# Out:
# {'a': 100, 'b': 200, 'c': 300, 'd': 400}

# %% [markdown]
# el metodo .update() agrega una nueva clave_valor a mi diccionario

# %%
datos2 = {"a":100,"b":200,"c":300}

# %%
datos2.update({"c": 300})
datos2
# Out:
# {'a': 100, 'b': 200, 'c': 300}

# %%
datos2.update({"c": 400})
datos2
# Out:
# {'a': 100, 'b': 200, 'c': 400}

# %%
datos2.update({"d": 300})
datos2
# Out:
# {'a': 100, 'b': 200, 'c': 300, 'd': 300}

# %% [markdown]
# al tratar modificar mi clave_valor con el metodo  .update me cambia hace que el valor que habia definadido a mi clave cambie y si pongo otra clave_valor me la agrega a mi diccionario sin importar si tiene el mismo valor a otra de mis claves ya existentes

# %% [markdown]
# Instrucción 4:

# %%
datos3 = {"a":10,"b":20,"c":30}

# %%
datos3.setdefault("di", 400)
# Out:
# 400

# %% [markdown]
# el metodo setdefault() nos da el unicamente el valor de la clave_valor que no esta en el diccionario definido

# %%
datos3 = {"a":10,"b":20,"c":30}

# %%
datos3.setdefault("b", 400)
# Out:
# 20

# %% [markdown]
# el metodo .setdefault al agregar una clave con un valor diferente nos da el valor que pusimos en el diccionario (datos3) sin importar el valor que que valor pongamos siempre nos da el valor resguistrado en el diccionario

# %%
datos3 = {"a":10,"b":20,"c":30}

# %%
datos3.setdefault("a", 10)
# Out:
# 10

# %% [markdown]
# el metodo setdefault al agregarel una clave valor repetida solo nos da el valor que le pusimos al diccionario

# %% [markdown]
# Parte III

# %%
def reconocernumeros(m):
 try:
     m = float(m)
if isinstance(m, int) and m >= 0:
 for n in range(0, (m+1)):
    if n == 1 or n == 0:
     print("El número es ", n)
 else:
   for x in range(2, n):
     if n % x == 0:
       print(n, 'es igual a', x, '*', n // x)
       break
elif m.is_integer and m >= 0:
  for n in range(0, int(m+1))
else:
    print(n, 'es un número primo')
else:
     print("El número no es natural")
# Out:
#   File "/tmp/ipykernel_288/623720046.py", line 4
#     if isinstance(m, int) and m >= 0:
#                                      ^
# SyntaxError: expected 'except' or 'finally' block

# %%
reconocernumeros(m)

# %% [markdown]
# codigo 2

# %%
consonates = "bcdfghjklmnñpqrstvwxyz"
consonates1 = consonates.upper()
consonates1
# Out:
# 'BCDFGHJKLMNÑPQRSTVWXYZ'

# %%
def contador_vocales1(palabra):
  letras = "aeioubcdfghjklmnñpqrstvwxyz"
  letras1 = letras.upper()
  numeros = "0123456789"
  espacio = " "

  contador = 0
  contador1 = 0
  contador2 = 0
  contador3 = 0
  contador4 = 0



  for letra in palabra:
    if letra in letras:
      contador += 1
    elif letra in letras1:
      contador1 += 1
    elif letra in numeros:
      contador3 += 1
    elif letra in espacio:
      contador4 += 1
    else:
      contador4 += 1

      contador2 += 1
      return({"Cantidad de letras minusculas:": contador,
 "Cantidad de letras mayusculas:": contador1,
 "Cantidad de numeros:": contador2,
 "cantidad de espacios": contador3,
 "cantidad de otros caracteres": contador4})

# %%
palabra = input("ingresa una cadena: ")
contador_vocales1(palabra)
# Out:
# ingresa una cadena: casA.43
# {'Cantidad de letras minusculas:': 3,
#  'Cantidad de letras mayusculas:': 1,
#  'Cantidad de numeros:': 1,
#  'cantidad de espacios': 0,
#  'cantidad de otros caracteres': 1}

# %% [markdown]
# primero definimos la funcion contador_vocales definimos 4 variables que son letras letras1 numeros, espacio con su respectivo valor leugo aplicamos contador para cada una de las 4 variables y para cada uno de las variables se le suma 1 si cumple cadauna de las condiciones y luego para cada contador le definimos lo que significa el resultado de cada contador
