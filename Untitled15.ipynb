# %% [markdown]
# <a href="https://colab.research.google.com/github/dubanmojica/programacion1/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def suma(z1, z2):
    return z1 + z2

def multiplicacion(z1, z2):
    return z1 * z2

def raiz_n(z, n):
    return z ** (1/n)

def leer_numero(mensaje):
    """Evita que el programa se cierre si el usuario escribe letras."""
    while True:
        try:
            return float(input(mensaje))
        except ValueError:
            print("Error: Ingrese un número válido.")

def pedir_complejo():
    print("\n número complejo ")
    real = leer_numero("Parte real: ")
    imag = leer_numero("Parte imaginaria: ")
    return complex(real, imag)
opcion = 0

while opcion != 4:
    print("1. Sumar")
    print("2. Multiplicar")
    print("3. Raíz n-ésima")
    print("4. Salir")

    try:
        opcion = int(input("\n Seleccione una opción: "))
    except ValueError:
        print("Error: Use los números del 1 al 4.")
        continue

    if opcion == 1:
        z1 = pedir_complejo()
        z2 = pedir_complejo()
        print(f" Resultado de la suma: {suma(z1, z2)}")

    elif opcion == 2:
        z1 = pedir_complejo()
        z2 = pedir_complejo()
        print(f" Resultado de la multiplicación: {multiplicacion(z1, z2)}")

    elif opcion == 3:
        z = pedir_complejo()
        n = leer_numero("Ingrese el índice n: ")
        if n != 0:
            print(f" Resultado de la raíz: {raiz_n(z, n)}")
        else:
            print("Error: El índice no puede ser 0.")

    elif opcion == 4:
        print("Programa finalizado.")

    else:
        print("Opción no válida. Intente de nuevo.")
# Out:
# 1. Sumar
# 2. Multiplicar
# 3. Raíz n-ésima
# 4. Salir
#
#  Seleccione una opción: 2
#
#  número complejo
# Parte real: 4
# Parte imaginaria: 5
#
#  número complejo
# Parte real: 3
# Parte imaginaria: 6
#  Resultado de la multiplicación: (-18+39j)
# 1. Sumar
# 2. Multiplicar
# 3. Raíz n-ésima
# 4. Salir
#
#  Seleccione una opción: 54
# Opción no válida. Intente de nuevo.
# 1. Sumar
# 2. Multiplicar
# 3. Raíz n-ésima
# 4. Salir
#
#  Seleccione una opción: 4
# Programa finalizado.
