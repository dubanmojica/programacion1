# %% [markdown]
# <a href="https://colab.research.google.com/github/dubanmojica/programacion1/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
materias = ["Cálculo I", "Álgebra Lineal", "Programación I", "Introducción a la Matemática"]
materias.append("Deportes")
print(f"Mis materias del semestre: {materias}")
# Out:
# Mis materias del semestre: ['Cálculo I', 'Álgebra Lineal', 'Programación I', 'Introducción a la Matemática', 'Deportes']

# %%
materias[0] = "Cálculo "
print(f"Primeras dos materias: {materias[:2]}")
# Out:
# Primeras dos materias: ['Cálculo ', 'Álgebra Lineal']

# %%
nota_parcial = 4.2
if nota_parcial >= 3.0:
    print(f"Resultado: ¡Aprobado con {nota_parcial}!")
else:
    print("Resultado: Debes recuperar el parcial.")
print("Buscando la materia 'Programación I' en mi lista...")
for m in materias:
    if m == "Programación I":
        print("¡Encontrada!")
        break
    print(f"Revisando: {m}")
# Out:
# Resultado: ¡Aprobado con 4.2!
# Buscando la materia 'Programación I' en mi lista...
# Revisando: Cálculo Diferencial
# Revisando: Álgebra Lineal
# ¡Encontrada!
