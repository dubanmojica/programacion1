# %% [markdown]
# <a href="https://colab.research.google.com/github/dubanmojica/programacion1/blob/main/Untitled28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 10 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_7502/3505272960.py in <cell line: 0>()
# ----> 1 x = 10 / 0
#
# ZeroDivisionError: division by zero

# %%
try:
  x = int(input("introduce un numero:   "))
  print(10 / x)
except:
  print("introduce un numero correcto")
# Out:
# introduce un numero:   0
# introduce un numero correcto

# %%
try:
  x = float(input("introduzca un numero"))
  print(10 / x)
except ZeroDivisionError:
  print("no se puede dividir por cero")
except ValueError:
  print("debe introducir un numero")
# Out:
# introduzca un numero2.6
# 3.846153846153846

# %%
try:
  lista = [1, 2, 3]
  print(lista[5])
except (IndexError, TypeError) as e:
  print(f"ocurrio un error: {e}")
# Out:
# ocurrio un error: list index out of range

# %%
lista = [1, 2, 3]
try:
   x = int(input("introduce el numero del indice"))
   print(lista[x])
except (IndexError, TypeError,ValueError) as e:
  print(f"ocurrio un error: {e}")
# Out:
# introduce el numero del indice-1
# 3

# %%
try:
  x = int(input("numero:  "))
except ValueError:
  print("error en la conversion")
else:
  print("todo salio bien")
finally:
  print("este bloque siempre se ejecuta")
# Out:
# numero:  54
# todo salio bien
# este bloque siempre se ejecuta

# %%
try:
  x = int(input("numero:  "))
  print("todo salio bien:", )
except ValueError:
  print("error en la conversion")
finally:
  print("este bloque siempre se ejecuta")
# Out:
# numero:  52
# todo salio bien:
# este bloque siempre se ejecuta

# %%
try:
  edad = int(input("edad:  "))
  if edad < 0:
    raise ValueError("la edad no puede ser negativa")
  print("edad valida:", edad)

except ValueError as e:
  print("error:", e)
# Out:
# edad:  -9
# error: la edad no puede ser negativa

# %% [markdown]
# tambien se pueden crear errores personalizados

# %% [markdown]
# tipos de errores en python

# %%
ValueError
# Out:
# ValueError

# %%
int(abc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7502/3746601669.py in <cell line: 0>()
# ----> 1 int(abc)
#
# NameError: name 'abc' is not defined

# %%
try:
  dato = input("ingresa un numero:")
  numero = float(dato)
  print("numero:", numero)
except ValueError as e:
  print("ValueErros:", e)
# Out:
# ingresa un numero:123.5
# numero: 123.5

# %%
complex(3+4j)
# Out:
# (3+4j)

# %%
try:
  dato = input("ingresa un numero:")
  numero = complex(dato)
  print("numero:", numero)
except ValueError as e:
  print("ValueErros:", e)
# Out:
# ingresa un numero:53
# numero: (53+0j)

# %% [markdown]
# typeError

# %%
"hola" +  5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7502/1301045647.py in <cell line: 0>()
# ----> 1 "hola" +  5
#
# TypeError: can only concatenate str (not "int") to str

# %%
"hola" +  "5"
# Out:
# 'hola5'

# %% [markdown]
# esta operando distintos elementos asi que no se puede operar, si opera dos cadenas si deja operar

# %%
"hola" *7
# Out:
# 'holaholaholaholaholaholahola'

# %%
"hola" * "fsa"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7502/2160457788.py in <cell line: 0>()
# ----> 1 "hola" * "fsa"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
try:
  texto = input("ingresa un texto")
  numero = int(input("ingresa un numero:  "))
  resultado = texto + numero
  print(resultado)
except TypeError as e:
  print("TypeError:", e)
# Out:
# ingresa un textohola
# ingresa un numero:  4
# TypeError: can only concatenate str (not "int") to str

# %%
try:
   texto = input("ingresa un texto")
   numero = float(input("ingresa un numero:  "))
   resultado = texto + numero
   print(resultado)
except TypeError as e:
    print("TypeError:", e)
except ValueError as e:
    print("ValueError:", e)
# Out:
# ingresa un textohola
# ingresa un numero:  mama
# ValueError: could not convert string to float: 'mama'

# %%
lista = [1, 2]
lista[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_7502/1494652019.py in <cell line: 0>()
#       1 lista = [1, 2]
# ----> 2 lista[5]
#
# IndexError: list index out of range

# %%
try:
   lista = input("ingresa elementos separados por coma.  ").split(",")
   indice = int(input("ingresa una posicion "))
   print("elemento:", lista[indice])
except IndexError as e:
   print("IndexError:", e)
except ValueError as e:
   print("ValueError: Debes introducir un numero para el indice.", e)
# Out:
# ingresa elementos separados por coma.  2, 3, 4, 5, a
# ingresa una posicion 4
# elemento:  a

# %%
try:
   lista = input("ingresa elementos separados por coma.  ").split(",")
   indice = int(input("ingresa una posicion "))
   print("elemento:", lista[indice])
except IndexError as e:
   print("IndexError:", e)
except ValueError as e:
   print("ValueError:", e)
# Out:
# ingresa elementos separados por coma.  1,2,3 4, 5, 6
# ingresa una posicion a
# ValueError: invalid literal for int() with base 10: 'a'

# %%
dic = ["a": 1]
dic["b"]
# Out:
#   File "/tmp/ipykernel_7502/1933654678.py", line 1
#     dic = ["a": 1]
#               ^
# SyntaxError: invalid syntax

# %%
try:
    dic = {1: 1, 2: 2}
    clave = int(input("ingresa una clave (a/b): "))
    print("valor:", dic[clave])
except KeyError as e:
    print("el usuario definido no exixte")
# Out:
# ingresa una clave (a/b): 1
# valor: 1

# %%
try:
    dic = {1: "a", "b": 2}
    clave = int(input("ingresa una clave (a/b): "))
    print("valor:", dic[clave])
except (KeyError, ValueError) as e:
    print("el usuario definido no exixte")
# Out:
# ingresa una clave (a/b): o
# el usuario definido no exixte

# %%
print(variable_no_definifa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7502/1250507224.py in <cell line: 0>()
# ----> 1 print(variable_no_definifa)
#
# NameError: name 'variable_no_definifa' is not defined

# %%
carro = 4
try:
    nombre_variable = input("escribe el nombre de una variable:  ")
    print(eval(nombre_variable))
except NameError as e:
  print("NameError:", e)
# Out:
# escribe el nombre de una variable:  carro
# 4

# %%
try:
    a = float(input("Numero 1 :  "))
    b = float(input("numero 2 :  "))
    print(a / b)
except ZeroDivisionError as e:
    print("al dividir entre cero se obtine una indeterminacion:", e)
# Out:
# Numero 1 :  4
# numero 2 :  1
# 4.0

# %%
try:
    a = int(input("numero :  "))
    b = input("cadena 1 :  ")
    print("producto":", a * b")
except ZeroDivisionError as e:
    print("al dividir entre cero se obtine una indeterminacion:", e)
# Out:
#   File "/tmp/ipykernel_7502/1825584062.py", line 4
#     print("producto":", a * b")
#                     ^
# SyntaxError: invalid syntax

# %%
try:
    a = int(input("numero :  "))
    b = input("cadena 1 :  ")
    print("producto":", a * b")
except ValueError as e:
    print("error en la conversion:", e)
# Out:
#   File "/tmp/ipykernel_7502/3407464808.py", line 4
#     print("producto":", a * b")
#                     ^
# SyntaxError: invalid syntax

# %%
x = [5]
x.append(10)
x
# Out:
# [5, 10]

# %%
try:
    dato = input

# %%
open("archivo_inexistente.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_7502/442054591.py in <cell line: 0>()
# ----> 1 open("archivo_inexistente.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'archivo_inexistente.txt'
