# %% [markdown]
# <a href="https://colab.research.google.com/github/dubanmojica/programacion1/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre = input("ingrese su nombre: ")
edad = input("ingrese su edad: ")
direccion = input("ingrese su direccion: ")
telefono = input("ingrese su telefono: ")

persona = {
    'nombre': nombre,
    'edad': edad,
    'direccion': direccion,
    'telefono': telefono
}

print(persona['nombre'], 'tiene', persona['edad'], 'años, vive en', persona['direccion'], 'y su número de teléfono es', persona['telefono'])
# Out:
# ingrese su nombre: duban
# ingrese su edad: 18
# ingrese su direccion: aguazul
# ingrese su telefono: 3219736542
# duban tiene 18 años, vive en aguazul y su número de teléfono es 3219736542

# %%
edad = int(input("ingresa tu edad"))
if edad >= 19:
  print ("eres mayor de edad")
else:
  print ("eres menor de edad")
# Out:
# ingresa tu edad17
# eres menor de edad

# %%
clave = input("ingresa tu clave")
if clave == "duban132":
  print("clave correcta")
else:
  print("clave incorrecta")
# Out:
# ingresa tu claveduban123
# clave incorrecta

# %%
while True:
    try:
        n = int(input("ingresa un valor"))
        if n % 2 == 0:
            print("el numero es par")
        else:
            print("el numero es impar")
            break
    except ValueError:
        print("el valor no es un numero")
# Out:
# ingresa un valor.
# el valor no es un numero
# ingresa un valor1
# el numero es impar
