# %% [markdown]
# <a href="https://colab.research.google.com/github/dubanmojica/programacion1/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# QUIZZ 26 DE MARZO

# %% [markdown]
# NOMBRE: DEYNER DUBAN MOJICA BERNAL

# %%
# %%writefile pedirnotas.py
def pedir_nombre():
    return input("ingrese el nombre del estudiante ")

def pedir_nota():
  n1 = float(input("ingrese la nota 1 "))
  n2 = float(input("ingrese la nota 2 "))
  n3 = float(input("ingrese la nota 3 "))
  n4 = float(input("ingrese la nota 4 "))

  return n1, n2, n3, n4
# Out:
# Overwriting pedirnotas.py

# %%
# %%writefile promedio.py
def calcular_promedio(n1, n2, n3, n4):
  return (n1 + n2 + n3 + n4)/4
# Out:
# Overwriting promedio.py

# %%
import importlib
import pedirnotas
importlib.reload(pedirnotas)
nombre = pedirnotas.pedir_nombre()
# Out:
# ingrese el nombre del estudiante duban mojica

# %%
import importlib
importlib.reload(pedirnotas)
notas = pedirnotas.pedir_nota()
# Out:
# ingrese la nota 1 4.2
# ingrese la nota 2 3.2
# ingrese la nota 3 4.2
# ingrese la nota 4 3.0

# %%
list(notas)
# Out:
# [4.2, 3.2, 4.2, 3.0]

# %%
import promedio
import importlib
importlib.reload(promedio)
prom = promedio.calcular_promedio(notas[0], notas[1], notas[2], notas[3])

print("estudiante:", nombre)
print("promedio:", prom)

if prom >= 3:
  print("aprobado")
else:
  print("reprobado")
# Out:
# estudiante: duban mojica
# promedio: 3.6500000000000004
# aprobado

# %%
# %%writefile calculos.py

def suma(a, b):
    return a + b
def multiplicar(a, b):
    return a * b
# Out:
# Writing calculos.py

# %%
# %%writefile mensajes.py

def saludar(nombre):
    return f"hola {nombre}"
# Out:
# Writing mensajes.py

# %%
# %%writefile promedio.py
import statistics
def calcular_promedio(n1, n2, n3, n4):
  return (n1 + n2 + n3 + n4) / 4
def mediana(n1, n2, n3, n4):
  return statistics.median([n1, n2, n3, n4])
# Out:
# Overwriting promedio.py

# %%
importlib.reload(promedio)
# Out:
# <module 'promedio' from '/content/promedio.py'>

# %%
list(notas)
# Out:
# [4.2, 3.2, 4.2, 3.0]

# %%
import promedio
importlib.reload(promedio)
prom = promedio.calcular_promedio(notas[0], notas[1], notas[2], notas[3])
mediana = promedio.mediana(notas[0], notas[1], notas[2], notas[3])

print("estudiante:", nombre)
print("promedio:", prom)
print("mediana: ", mediana)

if prom >= 3:
  print("aprobado")
else:
  print("reprobado")
# Out:
# estudiante: duban mojica
# promedio: 3.6500000000000004
# mediana:  3.7
# aprobado

# %%
# %%writefile src/operaciones.py
def dividir(a, b):
  return a / b
# Out:
# Overwriting src/operaciones.py

# %%
# %%writefile promedio.py
import statistics
def calcular_promedio(n1, n2, n3, n4):
  return (n1 + n2 + n3 + n4) / 4
def mediana(n1, n2, n3, n4):
  return statistics.median([n1, n2, n3, n4])
def moda(n1, n2, n3, n4):
  return(statistics.mode([n1, n2, n3, n4]))
# Out:
# Overwriting promedio.py

# %%
import promedio
importlib.reload(promedio)
prom = promedio.calcular_promedio(notas[0], notas[1], notas[2], notas[3])
mediana = promedio.mediana(notas[0], notas[1], notas[2], notas[3])
moda = promedio.moda(notas[0], notas[1], notas[2], notas[3])

print("estudiante:", nombre)
print("promedio:", prom)
print("mediana: ", mediana)
print("moda", moda)

if prom >= 3:
  print("aprobado")
else:
  print("reprobado")
# Out:
# estudiante: duban mojica
# promedio: 3.6500000000000004
# mediana:  3.7
# moda 4.2
# aprobado
